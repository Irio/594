# %%
import numpy as np
import pandas as pd

path = 'data/chamber_of_deputies_votes.csv'
dtype = {
    'congressperson_id': np.str,
    'session_number': np.str,
}
votes = pd.read_csv(path, dtype=dtype)
votes = votes \
    .query('term == 2015') \
    .query('legislative_session_number == 3') \
    .query('body == "chamber_of_deputies"')
votes = votes.drop_duplicates()
print(votes.shape)
votes.head()
# Out:
# (235, 17)
#    abstention_votes  blank_votes          ending_time first_president  \
# 1                 4            0  2017-12-06 01:31:27    RODRIGO MAIA
# 3                 1            0  2017-05-16 15:25:20             JHC
# 5                 1            0  2017-03-28 20:35:55   CARLOS MANATO
# 6                 2            0  2017-05-31 20:15:09    RODRIGO MAIA
# 8                 4            0  2017-02-07 18:17:32    RODRIGO MAIA
#
#                                                 name  no_votes  \
# 1  MPV  Nº 795/2017 - DTQ 11 - PV - ART. 7º DO TE...       222
# 3  MPV  Nº 756/2016 - REQUERIMENTO DE RETIRADA DE...       255
# 5        MPV  Nº 751/2016 - DTQ 1: PT - EMENDA Nº 34       179
# 6              PLP  Nº 54/2015 - SUBSTITUTIVO DA CFT        28
# 8  REQ  Nº 3970/2016 - URGÊNCIA PARA APRECIAÇÃO D...        17
#
#    obstruction_votes  president_votes  term  vote_number  votes  yes_votes  \
# 1                 19                1  2015         8100    369        123
# 3                 61                1  2015         7538    336         18
# 5                  0                1  2015         7445    426        245
# 6                  5                1  2015         7594    441        405
# 8                  0                1  2015         7363    336        314
#
#                   body legislative_schedule  legislative_session_number  \
# 1  chamber_of_deputies     ordinary_session                           3
# 3  chamber_of_deputies     ordinary_session                           3
# 5  chamber_of_deputies     ordinary_session                           3
# 6  chamber_of_deputies     ordinary_session                           3
# 8  chamber_of_deputies     ordinary_session                           3
#
#            schedule session_number
# 1   special_session            378
# 3   special_session            118
# 5  ordinary_session            049
# 6   special_session            141
# 8   special_session            003

# %%
path = 'data/chamber_of_deputies_votes_congresspeople.csv'
dtype = {
    'congressperson_id': np.str,
    'session_number': np.str,
}
votes_congresspeople = pd.read_csv(path, dtype=dtype)
votes_congresspeople = votes_congresspeople \
    .query('term == 2015') \
    .query('legislative_session_number == 3') \
    .query('body == "chamber_of_deputies"')
votes_congresspeople = votes_congresspeople.drop_duplicates()
print(votes_congresspeople.shape)
votes_congresspeople.head()
# Out:
# (85275, 11)
#                 name vote party    state congressperson_id  term  \
# 513   CARLOS ANDRADE   no   PHS  Roraima                 3  2015
# 514  HIRAN GONÇALVES   no    PP  Roraima                 4  2015
# 515         SHÉRIDAN   no  PSDB  Roraima                 8  2015
# 516      ANDRÉ ABDON   no    PP    Amapá                 9  2015
# 517    CABUÇU BORGES   no  PMDB    Amapá                14  2015
#
#                     body legislative_schedule  legislative_session_number  \
# 513  chamber_of_deputies     ordinary_session                           3
# 514  chamber_of_deputies     ordinary_session                           3
# 515  chamber_of_deputies     ordinary_session                           3
# 516  chamber_of_deputies     ordinary_session                           3
# 517  chamber_of_deputies     ordinary_session                           3
#
#             schedule session_number
# 513  special_session            064
# 514  special_session            064
# 515  special_session            064
# 516  special_session            064
# 517  special_session            064

# %%
votes['acceptance_rate'] = votes['yes_votes'] / votes['votes']

# %%
vote_cols = [col for col in votes.columns if col[-6:] == '_votes']

def outcome(row):
    row = row[vote_cols].to_dict()
    return max(row, key=row.get)[:-6]

votes['outcome'] = votes.apply(outcome, axis=1)

# %%
cols = ['name', 'votes', 'schedule', 'session_number', 'acceptance_rate']

votes \
    .query('outcome == "yes"') \
    .sort_values('acceptance_rate', ascending=False)[cols].head()
# Out:
#                                                   name  votes  \
# 113  PEC  Nº 212/2016 - PROPOSTA DE EMENDA À CONSTI...    391
# 172             PLP  Nº 171/2015 - SUBSTITUTIVO DA CFT    334
# 215     PLP  Nº 163/2015 - PROJETO DE LEI COMPLEMENTAR    405
# 476  REQ  Nº 7701/2017 - URGÊNCIA PARA APRECIAÇÃO D...    295
# 464  PEC  Nº 212/2016 - SUBSTITUTIVO DA COMISSÃO ES...    368
#
#              schedule session_number  acceptance_rate
# 113   special_session            381         0.997442
# 172   special_session            381         0.994012
# 215  ordinary_session            004         0.992593
# 476   special_session            379         0.989831
# 464   special_session            366         0.989130

# %%
keys = [
    'session_number',
    'body',
    'legislative_schedule',
    'schedule',
    'term',
    'legislative_session_number',
]

votes_congresspeople = votes_congresspeople \
    .merge(votes, on=keys, how='left', suffixes=('', '_vote'))
votes_congresspeople.iloc[0]
# Out:
# name                                                             CARLOS ANDRADE
# vote                                                                         no
# party                                                                       PHS
# state                                                                   Roraima
# congressperson_id                                                             3
# term                                                                       2015
# body                                                        chamber_of_deputies
# legislative_schedule                                           ordinary_session
# legislative_session_number                                                    3
# schedule                                                        special_session
# session_number                                                              064
# abstention_votes                                                              3
# blank_votes                                                                   0
# ending_time                                                 2017-04-05 23:31:43
# first_president                                                    RODRIGO MAIA
# name_vote                     PLP  Nº 343/2017 - REQUERIMENTO DE ENCERRAMENT...
# no_votes                                                                     32
# obstruction_votes                                                            78
# president_votes                                                               1
# vote_number                                                                7458
# votes                                                                       371
# yes_votes                                                                   257
# acceptance_rate                                                        0.692722
# outcome                                                                     yes
# Name: 0, dtype: object

# %%
def agg(data):
    times_right = data['vote'] == data['outcome']
    return pd.Series({
        'times_right': times_right.sum(),
    })

votes_congresspeople \
    .groupby(['name']) \
    .apply(agg) \
    .sort_values('times_right', ascending=False)
# Out:
#                           times_right
# name
# TENENTE LÚCIO                     218
# MARCIO ALVINO                     217
# CARLOS HENRIQUE GAGUIM            217
# DELEGADO EDSON MOREIRA            212
# HERCULANO PASSOS                  211
# JONES MARTINS                     211
# EDUARDO BARBOSA                   210
# ALBERTO FRAGA                     210
# ROBERTO ALVES                     210
# MIGUEL LOMBARDI                   209
# MAURO PEREIRA                     208
# DILCEU SPERAFICO                  207
# TIRIRICA                          207
# ÁTILA LIRA                        207
# PEDRO FERNANDES                   206
# LOBBE NETO                        206
# JOSÉ FOGAÇA                       205
# BETINHO GOMES                     205
# HÉLIO LEITE                       205
# MARCELO CASTRO                    205
# ZÉ SILVA                          205
# GERALDO RESENDE                   205
# MARCUS PESTANA                    204
# CACÁ LEÃO                         204
# PAULO FEIJÓ                       204
# IZAQUE SILVA                      204
# ROBERTO BRITTO                    204
# JOSÉ NUNES                        204
# ADELSON BARRETO                   203
# LUIZ CLÁUDIO                      203
# ...                               ...
# ROCHA LOURES                       43
# MÁRIO NEGROMONTE JR.               41
# PR. LUCIANO BRAGA                  35
# LUCIANO BIVAR                      32
# SANDES JÚNIOR                      30
# BRUNO ARAÚJO                       26
# CHICO D ANGELO                     26
# FERNANDO TORRES                    25
# TIA ERON                           21
# JOSÉ OTÁVIO GERMANO                20
# JULIÃO AMIN CASTRO                 16
# EDINHO BEZ                         13
# RONALDO NOGUEIRA                    9
# MENDONÇA FILHO                      9
# LOURIVAL GOMES                      9
# FERNANDO COELHO FILHO               8
# DAGOBERTO                           8
# RODRIGO MAIA                        5
# ANTONIO IMBASSAHY                   5
# LEONARDO PICCIANI                   4
# SEBASTIÃO OLIVEIRA                  3
# MARX BELTRÃO                        3
# MAURÍCIO QUINTELLA LESSA            3
# SARNEY FILHO                        2
# OSMAR TERRA                         1
# JOSIAS GOMES                        1
# RAUL JUNGMANN                       0
# FELIPE CARRERAS                     0
# JULIÃO AMIN                         0
# CAPITÃO FÁBIO ABREU                 0
#
# [548 rows x 1 columns]
